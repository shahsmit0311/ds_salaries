# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
edu=pd.read_csv("~/Desktop/ds_salaries.csv")

# %%
edu
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %%
edu.head()
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2023               SE              FT  Principal Data Scientist
# 1       2023               MI              CT               ML Engineer
# 2       2023               MI              CT               ML Engineer
# 3       2023               SE              FT            Data Scientist
# 4       2023               SE              FT            Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   80000             EUR          85847                 ES           100
# 1   30000             USD          30000                 US           100
# 2   25500             USD          25500                 US           100
# 3  175000             USD         175000                 CA           100
# 4  120000             USD         120000                 CA           100
#
#   company_location company_size
# 0               ES            L
# ...

# %%
edu.tail()
# Out:
#       work_year experience_level employment_type                 job_title  \
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
#        salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 3750   412000             USD         412000                 US           100
# 3751   151000             USD         151000                 US           100
# 3752   105000             USD         105000                 US           100
# 3753   100000             USD         100000                 US           100
# 3754  7000000             INR          94665                 IN            50
#
#      company_location company_size
# ...

# %%
edu.describe()
# Out:
#          work_year        salary  salary_in_usd  remote_ratio
# count  3755.000000  3.755000e+03    3755.000000   3755.000000
# mean   2022.373635  1.906956e+05  137570.389880     46.271638
# std       0.691448  6.716765e+05   63055.625278     48.589050
# min    2020.000000  6.000000e+03    5132.000000      0.000000
# 25%    2022.000000  1.000000e+05   95000.000000      0.000000
# 50%    2022.000000  1.380000e+05  135000.000000      0.000000
# 75%    2023.000000  1.800000e+05  175000.000000    100.000000
# max    2023.000000  3.040000e+07  450000.000000    100.000000

# %%
edu['salary_in_usd']
# Out:
# 0        85847
# 1        30000
# 2        25500
# 3       175000
# 4       120000
#          ...
# 3750    412000
# 3751    151000
# 3752    105000
# 3753    100000
# 3754     94665
# Name: salary_in_usd, Length: 3755, dtype: int64

# %%
edu['salary']
# Out:
# 0         80000
# 1         30000
# 2         25500
# 3        175000
# 4        120000
#          ...
# 3750     412000
# 3751     151000
# 3752     105000
# 3753     100000
# 3754    7000000
# Name: salary, Length: 3755, dtype: int64

# %%
edu[100:110]
# Out:
#      work_year experience_level employment_type           job_title  salary  \
# 100       2023               SE              FT        Data Analyst  104300
# 101       2023               SE              FT        Data Analyst  145000
# 102       2023               SE              FT        Data Analyst   65000
# 103       2023               SE              FT       Data Engineer  165000
# 104       2023               SE              FT       Data Engineer  132300
# 105       2023               SE              FT       Data Engineer  179170
# 106       2023               SE              FT       Data Engineer   94300
# 107       2023               SE              FT  Analytics Engineer  152500
# 108       2023               SE              FT  Analytics Engineer  116450
# 109       2023               SE              FT       Data Engineer  247300
#
#     salary_currency  salary_in_usd employee_residence  remote_ratio  \
# ...

# %%
edu.loc[900:911, ["salary", "salary_currency","salary_in_usd","employee_residence"]]
# Out:
#      salary salary_currency  salary_in_usd employee_residence
# 900  200000             USD         200000                 US
# 901  125000             USD         125000                 US
# 902  201000             USD         201000                 US
# 903  122000             USD         122000                 US
# 904  204500             USD         204500                 US
# 905  142200             USD         142200                 US
# 906  155000             USD         155000                 US
# 907  140000             USD         140000                 US
# 908  205920             USD         205920                 US
# 909  171600             USD         171600                 US
# 910  121500             USD         121500                 US
# 911   78000             USD          78000                 US

# %%
edu[edu['salary_in_usd'] > 250000].tail()
# Out:
#       work_year experience_level employment_type  \
# 3615       2021               SE              FT
# 3675       2021               EX              CT
# 3697       2020               EX              FT
# 3747       2021               MI              FT
# 3750       2020               SE              FT
#
#                                job_title  salary salary_currency  \
# 3615                         ML Engineer  256000             USD
# 3675            Principal Data Scientist  416000             USD
# 3697            Director of Data Science  325000             USD
# 3747  Applied Machine Learning Scientist  423000             USD
# 3750                      Data Scientist  412000             USD
#
#       salary_in_usd employee_residence  remote_ratio company_location  \
# 3615         256000                 US           100               US
# 3675         416000                 US           100               US
# ...

# %%
edu[edu["salary"].isnull()].head()
# Out:
# Empty DataFrame
# Columns: [work_year, experience_level, employment_type, job_title, salary, salary_currency, salary_in_usd, employee_residence, remote_ratio, company_location, company_size]
# Index: []

# %%
edu[edu["remote_ratio"].isnull()].head()
# Out:
# Empty DataFrame
# Columns: [work_year, experience_level, employment_type, job_title, salary, salary_currency, salary_in_usd, employee_residence, remote_ratio, company_location, company_size]
# Index: []

# %%
edu.max(axis = 0)
# Out:
# work_year                             2023
# experience_level                        SE
# employment_type                         PT
# job_title             Staff Data Scientist
# salary                            30400000
# salary_currency                        USD
# salary_in_usd                       450000
# employee_residence                      VN
# remote_ratio                           100
# company_location                        VN
# company_size                             S
# dtype: object

# %%
print ("Pandas max function:", edu['salary'].max())
print ("Python max function:", max(edu['salary']))
# Out:
# Pandas max function: 30400000
# Python max function: 30400000

# %%
s = edu["salary_in_usd"]/100
s.head()
# Out:
# 0     858.47
# 1     300.00
# 2     255.00
# 3    1750.00
# 4    1200.00
# Name: salary_in_usd, dtype: float64

# %%
s = edu["salary_in_usd"].apply(np.sqrt)
s.head()
# Out:
# 0    292.996587
# 1    173.205081
# 2    159.687194
# 3    418.330013
# 4    346.410162
# Name: salary_in_usd, dtype: float64

# %%
s= edu["salary_in_usd"].apply(lambda d:d**2)
s.head()
# Out:
# 0     7369707409
# 1      900000000
# 2      650250000
# 3    30625000000
# 4    14400000000
# Name: salary_in_usd, dtype: int64

# %%
edu["salary_norm"]=edu["salary_in_usd"]/edu["salary_in_usd"].max()
edu.tail()
# Out:
#       work_year experience_level employment_type                 job_title  \
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
#        salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 3750   412000             USD         412000                 US           100
# 3751   151000             USD         151000                 US           100
# 3752   105000             USD         105000                 US           100
# 3753   100000             USD         100000                 US           100
# 3754  7000000             INR          94665                 IN            50
#
# ...

# %%
edu.drop("salary_norm", axis=1, inplace=True)
edu.head()
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2023               SE              FT  Principal Data Scientist
# 1       2023               MI              CT               ML Engineer
# 2       2023               MI              CT               ML Engineer
# 3       2023               SE              FT            Data Scientist
# 4       2023               SE              FT            Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   80000             EUR          85847                 ES           100
# 1   30000             USD          30000                 US           100
# 2   25500             USD          25500                 US           100
# 3  175000             USD         175000                 CA           100
# 4  120000             USD         120000                 CA           100
#
#   company_location company_size
# 0               ES            L
# ...

# %%
new_row = pd.DataFrame({"work_year": [2022], "experience_level": ["SE"], "employment_type": ["FT"], "job_title": ["Meme Engineer"], "salary": [300000], "salary_currency": ["USD"], "salary_in_usd": [300000], "employee_residence": ["US"], "remote_ratio": [100], "company_location": ["US"],"company_size": ["L"]})
edu = pd.concat([edu, new_row], ignore_index=True)
edu.tail()
# Out:
#       work_year experience_level employment_type                 job_title  \
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
# 3755       2022               SE              FT             Meme Engineer
#
#        salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 3751   151000             USD         151000                 US           100
# 3752   105000             USD         105000                 US           100
# 3753   100000             USD         100000                 US           100
# 3754  7000000             INR          94665                 IN            50
# 3755   300000             USD         300000                 US           100
#
#      company_location company_size
# ...

# %%
edu.drop(max(edu.index), axis = 0, inplace = True)
edu.tail()
# Out:
#       work_year experience_level employment_type                 job_title  \
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
#        salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 3750   412000             USD         412000                 US           100
# 3751   151000             USD         151000                 US           100
# 3752   105000             USD         105000                 US           100
# 3753   100000             USD         100000                 US           100
# 3754  7000000             INR          94665                 IN            50
#
#      company_location company_size
# ...

# %%
eduDrop = edu.dropna(how = 'any', subset = ["salary_in_usd"])
edu.head()
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2023               SE              FT  Principal Data Scientist
# 1       2023               MI              CT               ML Engineer
# 2       2023               MI              CT               ML Engineer
# 3       2023               SE              FT            Data Scientist
# 4       2023               SE              FT            Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   80000             EUR          85847                 ES           100
# 1   30000             USD          30000                 US           100
# 2   25500             USD          25500                 US           100
# 3  175000             USD         175000                 CA           100
# 4  120000             USD         120000                 CA           100
#
#   company_location company_size
# 0               ES            L
# ...

# %%
eduFilled = edu.fillna(value = {"salary_in_usd": 0})
eduFilled.head()
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2023               SE              FT  Principal Data Scientist
# 1       2023               MI              CT               ML Engineer
# 2       2023               MI              CT               ML Engineer
# 3       2023               SE              FT            Data Scientist
# 4       2023               SE              FT            Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   80000             EUR          85847                 ES           100
# 1   30000             USD          30000                 US           100
# 2   25500             USD          25500                 US           100
# 3  175000             USD         175000                 CA           100
# 4  120000             USD         120000                 CA           100
#
#   company_location company_size
# 0               ES            L
# ...

# %%
edu.sort_values(by = 'salary_in_usd', ascending = False, inplace = True)
edu.head()
# Out:
#       work_year experience_level employment_type  \
# 3522       2020               MI              FT
# 2011       2022               MI              FT
# 528        2023               SE              FT
# 3747       2021               MI              FT
# 3675       2021               EX              CT
#
#                                job_title   salary salary_currency  \
# 3522                  Research Scientist   450000             USD
# 2011                        Data Analyst   350000             GBP
# 528                         AI Scientist  1500000             ILS
# 3747  Applied Machine Learning Scientist   423000             USD
# 3675            Principal Data Scientist   416000             USD
#
#       salary_in_usd employee_residence  remote_ratio company_location  \
# 3522         450000                 US             0               US
# 2011         430967                 GB             0               GB
# ...

# %%
edu.sort_index(axis = 0, ascending = True, inplace = True)
edu.head()
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2023               SE              FT  Principal Data Scientist
# 1       2023               MI              CT               ML Engineer
# 2       2023               MI              CT               ML Engineer
# 3       2023               SE              FT            Data Scientist
# 4       2023               SE              FT            Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   80000             EUR          85847                 ES           100
# 1   30000             USD          30000                 US           100
# 2   25500             USD          25500                 US           100
# 3  175000             USD         175000                 CA           100
# 4  120000             USD         120000                 CA           100
#
#   company_location company_size
# 0               ES            L
# ...

# %%
group = edu[["job_title","salary_in_usd"]].groupby('job_title').mean()
group.head()
# Out:
#                                salary_in_usd
# job_title
# 3D Computer Vision Researcher   21352.250000
# AI Developer                   136666.090909
# AI Programmer                   55000.000000
# AI Scientist                   110120.875000
# Analytics Engineer             152368.631068

# %%
filtered_data = edu[edu["work_year"] > 2020]
pivedu = pd.pivot_table(filtered_data , values = 'salary_in_usd', index = ['experience_level'], columns = ['work_year'])
pivedu.head()
# Out:
# work_year                  2021           2022           2023
# experience_level
# EN                 54905.254545   77006.024194   95283.966102
# EX                186128.000000  188260.292683  203705.683333
# MI                 82116.934783  101305.598338  116297.596875
# SE                126085.356164  147659.688049  159568.928516

# %%
pivedu.loc[['EN','SE'], [2021,2023]]
# Out:
# work_year                  2021           2023
# experience_level
# EN                 54905.254545   95283.966102
# SE                126085.356164  159568.928516

# %%
pivedu = pivedu.dropna()

# %%
pivedu.rank(ascending = False, method = 'first').head()
# Out:
# work_year         2021  2022  2023
# experience_level
# EN                 4.0   4.0   4.0
# EX                 1.0   1.0   1.0
# MI                 3.0   3.0   3.0
# SE                 2.0   2.0   2.0

# %%
totalSum = pivedu.sum(axis = 1)
totalSum.rank(ascending = False, method = 'dense').sort_values().head()
# Out:
# experience_level
# EX    1.0
# SE    2.0
# MI    3.0
# EN    4.0
# dtype: float64

# %%
totalSum = pivedu.sum(axis = 1).sort_values(ascending = False)
totalSum.plot(kind = 'bar', style = 'b', alpha = 0.4, title = "Salary At Different Experience Level")
# Out:
# <Axes: title={'center': 'Salary At Different Experience Level'}, xlabel='experience_level'>

# %%
my_colors = ['b', 'r', 'g']
ax = pivedu.plot(kind = 'barh',stacked = True ,color = my_colors)
ax.legend(loc = 'center left', bbox_to_anchor = (1, .5))
